# %%
import requests
import urllib.request
import pandas as pd
import json
from pprint import pprint

# %%
wine = "desktop/wine.json"
wine_df = pd.read_json(wine)
import numpy as np
import matplotlib.pyplot as plt

# %%
clean_wine= wine_df[["country","description", "points", "taster_name", "taster_twitter_handle", "title", "winery"]]
clean_wine.head()
# Out:
#     country                                        description  points  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2        US  Tart and snappy, the flavors of lime flesh and...      87
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87
# 4        US  Much like the regular bottling from 2012, this...      87
#
#           taster_name taster_twitter_handle  \
# 0       Kerin O’Keefe          @kerinokeefe
# 1          Roger Voss            @vossroger
# 2        Paul Gregutt           @paulgwine
# 3  Alexander Peartree                  None
# 4        Paul Gregutt           @paulgwine
#
#                                                title               winery
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)              Nicosia
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Quinta dos Avidagos
# ...

# %%
url = "https://api.globalwinescore.com/globalwinescores/latest/"
articles = requests.get(url, headers={'Accept': 'application/json', 'Authorization': 'Token ea6b4f7553f48c8c614f38f11637307617531a12'}).json()
wine_json = json.dumps(articles['results'])
wine_json
# Out:
# '[{"wine": "Vietti, Rocche di Castiglione , Barolo", "wine_id": 148539, "wine_slug": "vietti-rocche-di-castiglione-barolo", "appellation": "Barolo", "appellation_slug": "barolo", "color": "Red", "wine_type": "", "regions": ["Piedmont"], "country": "Italy", "classification": null, "vintage": "2014", "date": "2018-12-31", "is_primeurs": false, "score": 95.89, "confidence_index": "C+", "journalist_count": 3, "lwin": 1106370, "lwin_11": 11063702014}, {"wine": "Caiarossa, Toscana", "wine_id": 23246, "wine_slug": "caiarossa-toscana", "appellation": "Toscana", "appellation_slug": "toscana", "color": "Red", "wine_type": "", "regions": ["Tuscany"], "country": "Italy", "classification": null, "vintage": "2015", "date": "2018-12-31", "is_primeurs": false, "score": 91.98, "confidence_index": "A", "journalist_count": 3, "lwin": null, "lwin_11": null}, {"wine": "Catena Zapata, \'Catena Alta\' Chardonnay, Blanco, Mendoza", "wine_id": 28750, "wine_slug": "catena-zapata-catena-alta-chardonnay-blanco-
# ...

# %%
global_df = pd.read_json(wine_json)
global_df.head()
# Out:
#      appellation appellation_slug classification  color confidence_index  \
# 0         Barolo           barolo           None    Red               C+
# 1        Toscana          toscana           None    Red                A
# 2        Mendoza          mendoza           None  White                A
# 3         Alsace           alsace           None  White                B
# 4  Martinborough    martinborough           None    Red                B
#
#        country       date  is_primeurs  journalist_count       lwin  \
# 0        Italy 2018-12-31        False                 3  1106370.0
# 1        Italy 2018-12-31        False                 3        NaN
# 2    Argentina 2018-12-31        False                 3        NaN
# 3       France 2018-12-31        False                 3        NaN
# 4  New Zealand 2018-12-31        False                 3        NaN
#
#         lwin_11        regions  score  vintage  \
# 0  1.106370e+10     [Piedmont]  95.89     2014
# ...
